# %% [markdown]
# <a href="https://colab.research.google.com/github/Raihannpc/sistem-panen/blob/main/sistem_panen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=== SISTEM PENCATATAN HASIL PANEN ===")

nama_komoditas = input("Nama komoditas: ")
jumlah = float(input("Jumlah hasil panen (kg): "))
harga = float(input("Harga per kg: "))

total = jumlah * harga

print("\n=== HASIL PENCATATAN ===")
print("Komoditas :", nama_komoditas)
print("Jumlah    :", jumlah, "kg")
print("Harga/kg  : Rp", harga)
print("Total     : Rp", total)
# Out:
# === SISTEM PENCATATAN HASIL PANEN ===
# Nama komoditas: Cabai
# Jumlah hasil panen (kg): 5
# Harga per kg: 60000
#
# === HASIL PENCATATAN ===
# Komoditas : Cabai
# Jumlah    : 5.0 kg
# Harga/kg  : Rp 60000.0
# Total     : Rp 300000.0
